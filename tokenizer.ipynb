# %%
! pip install miditok
# Out:
# Requirement already satisfied: miditok in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (3.0.5.post1)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from miditok) (0.26.3)
# Requirement already satisfied: numpy>=1.19 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from miditok) (1.26.4)
# Requirement already satisfied: symusic>=0.5.0 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from miditok) (0.5.7)
# Requirement already satisfied: tokenizers>=0.13.0 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from miditok) (0.20.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from miditok) (4.67.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (6.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from huggingface-hub>=0.16.4->miditok) (4.12.2)
# Requirement already satisfied: pySmartDL in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from symusic>=0.5.0->miditok) (1.3.4)
# Requirement already satisfied: platformdirs in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from symusic>=0.5.0->miditok) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from requests->huggingface-hub>=0.16.4->miditok) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ml_ai/lib/python3.11/site-packages (from requests->huggingface-hub>=0.16.4->miditok) (2024.8.30)

# %%
from miditok import REMI, TokenizerConfig
from symusic import Score
from miditok.pytorch_data import DatasetMIDI, DataCollator
from torch.utils.data import DataLoader


# Creating a multitrack tokenizer, read the doc to explore all the parameters
config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
tokenizer = REMI(config)

# Loads a midi, converts to tokens, and back to a MIDI
midi = Score("ty_april.mid")
tokens = tokenizer(midi)  # calling the tokenizer will automatically detect MIDIs, paths and tokens
converted_back_midi = tokenizer(tokens)  # PyTorch, Tensorflow and Numpy tensors are supported

# %%
tokens
# Out:
# TokSequence(tokens=['Bar_None', 'Position_20', 'Program_0', 'Pitch_65', 'Velocity_55', 'Duration_0.4.8', 'Position_24', 'Program_0', 'Pitch_58', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_67', 'Velocity_55', 'Duration_1.4.8', 'Position_28', 'Program_0', 'Chord_maj', 'Program_0', 'Pitch_58', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Bar_None', 'Position_0', 'Program_0', 'Chord_maj', 'Program_0', 'Pitch_58', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_31', 'Duration_0.4.8', 'Position_4', 'Program_0', 'Chord_7maj', 'Program_0', 'Pitch_58', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_69', 'Velocity_55', 'Duration_1.0.8', 'Position_8', 'Program_0', 'Chord_maj', 'Program_0', 'Pitch_58', 'Velocity_23', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_23', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_31', 'Duration_0.4.8', 'Position_12', 'Program_0', 'Pitch_70', 'Velocity_55', 'Duration_0.4.8', 'Position_16', 'Program_0', 'Pitch_74', 'Velocity_63', 'Duration_1.4.8', 'Position_20', 'Program_0', 'Pitch_57', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_24', 'Program_0', 'Pitch_57', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_28', 'Program_0', 'Pitch_57', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_72', 'Velocity_55', 'Duration_1.0.8', 'Bar_None', 'Position_0', 'Program_0', 'Pitch_57', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_4', 'Program_0', 'Pitch_65', 'Velocity_55', 'Duration_0.4.8', 'Position_8', 'Program_0', 'Pitch_71', 'Velocity_55', 'Duration_1.4.8', 'Position_12', 'Program_0', 'Pitch_56', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_16', 'Program_0', 'Pitch_56', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_20', 'Program_0', 'Pitch_56', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_72', 'Velocity_63', 'Duration_1.0.8', 'Position_24', 'Program_0', 'Pitch_56', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_62', 'Velocity_31', 'Duration_0.4.8', 'Program_0', 'Pitch_65', 'Velocity_39', 'Duration_0.4.8', 'Position_28', 'Program_0', 'Pitch_74', 'Velocity_55', 'Duration_0.4.8', 'Bar_None', 'Position_0', 'Program_0', 'Pitch_77', 'Velocity_63', 'Duration_1.4.8', 'Position_4', 'Program_0', 'Pitch_55', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_60', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_47', 'Duration_0.4.8', 'Position_8', 'Program_0', 'Pitch_55', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_60', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_47', 'Duration_0.4.8', 'Position_12', 'Program_0', 'Pitch_55', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_60', 'Velocity_39', 'Duration_0.4.8', 'Program_0', 'Pitch_63', 'Velocity_47', 'Duration_0.4.8', 'Program_0', 'Pitch_75', 'Velocity_63', 'Duration_1.0.8', 'Position_1 ...

# %%
midis = ["ty_april.mid"]
print(midis)

# Create a Dataset, a DataLoader and a collator to train a model
dataset = DatasetMIDI(
files_paths=midis,
tokenizer=tokenizer,
max_seq_len=1024,
bos_token_id=tokenizer["BOS_None"],
eos_token_id=tokenizer["EOS_None"])

collator = DataCollator(tokenizer.pad_token_id, copy_inputs_as_labels=True)
dataloader = DataLoader(dataset, batch_size=64, collate_fn=collator)

for batch, encodings in enumerate(dataloader):
    print(encodings["attention_mask"])
# Out:
# ['ty_april.mid']
# tensor([[1, 1, 1,  ..., 1, 1, 1]], dtype=torch.int32)
